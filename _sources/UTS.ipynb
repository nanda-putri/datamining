# %% [markdown]
# # UTS

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
url = "https://raw.githubusercontent.com/nanda-putri/datamining/gh-pages/Data%20UTS.csv"
data = pd.read_csv(url)
data.head()
# Out:
#    Age        BMI  Glucose  Insulin      HOMA   Leptin  Adiponectin  Resistin  \
# 0   48  23.500000       70    2.707  0.467409   8.8071     9.702400   7.99585
# 1   83  20.690495       92    3.115  0.706897   8.8438     5.429285   4.06405
# 2   82  23.124670       91    4.498  1.009651  17.9393    22.432040   9.27715
# 3   68  21.367521       77    3.226  0.612725   9.8827     7.169560  12.76600
# 4   86  21.111111       92    3.549  0.805386   6.6994     4.819240  10.57635
#
#      MCP.1  Classification
# 0  417.114               1
# 1  468.786               1
# 2  554.697               1
# 3  928.220               1
# 4  773.920               1

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 116 entries, 0 to 115
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Age             116 non-null    int64
#  1   BMI             116 non-null    float64
#  2   Glucose         116 non-null    int64
#  3   Insulin         116 non-null    float64
#  4   HOMA            116 non-null    float64
#  5   Leptin          116 non-null    float64
#  6   Adiponectin     116 non-null    float64
#  7   Resistin        116 non-null    float64
#  8   MCP.1           116 non-null    float64
#  9   Classification  116 non-null    int64
# dtypes: float64(7), int64(3)
# memory usage: 9.2 KB

# %% [markdown]
# Finding Missing Value

# %%
data.isna().sum()
# Out:
# Age               0
# BMI               0
# Glucose           0
# Insulin           0
# HOMA              0
# Leptin            0
# Adiponectin       0
# Resistin          0
# MCP.1             0
# Classification    0
# dtype: int64

# %% [markdown]
# Describe data

# %%
data.describe()
# Out:
#               Age         BMI     Glucose     Insulin        HOMA      Leptin  \
# count  116.000000  116.000000  116.000000  116.000000  116.000000  116.000000
# mean    57.301724   27.582111   97.793103   10.012086    2.694988   26.615080
# std     16.112766    5.020136   22.525162   10.067768    3.642043   19.183294
# min     24.000000   18.370000   60.000000    2.432000    0.467409    4.311000
# 25%     45.000000   22.973205   85.750000    4.359250    0.917966   12.313675
# 50%     56.000000   27.662416   92.000000    5.924500    1.380939   20.271000
# 75%     71.000000   31.241442  102.000000   11.189250    2.857787   37.378300
# max     89.000000   38.578759  201.000000   58.460000   25.050342   90.280000
#
#        Adiponectin    Resistin        MCP.1  Classification
# count   116.000000  116.000000   116.000000      116.000000
# mean     10.180874   14.725966   534.647000        1.551724
# std       6.843341   12.390646   345.912663        0.499475
# min       1.656020    3.210000    45.843000        1.000000
# 25%       5.474283    6.881763   269.978250        1.000000
# 50%       8.352692   10.827740   471.322500        2.000000
# 75%      11.815970   17.755207   700.085000        2.000000
# max      38.040000   82.100000  1698.440000        2.000000

# %%
data.corr()
# Out:
#                      Age       BMI   Glucose   Insulin      HOMA    Leptin  \
# Age             1.000000  0.008530  0.230106  0.032495  0.127033  0.102626
# BMI             0.008530  1.000000  0.138845  0.145295  0.114480  0.569593
# Glucose         0.230106  0.138845  1.000000  0.504653  0.696212  0.305080
# Insulin         0.032495  0.145295  0.504653  1.000000  0.932198  0.301462
# HOMA            0.127033  0.114480  0.696212  0.932198  1.000000  0.327210
# Leptin          0.102626  0.569593  0.305080  0.301462  0.327210  1.000000
# Adiponectin    -0.219813 -0.302735 -0.122121 -0.031296 -0.056337 -0.095389
# Resistin        0.002742  0.195350  0.291327  0.146731  0.231101  0.256234
# MCP.1           0.013462  0.224038  0.264879  0.174356  0.259529  0.014009
# Classification -0.043555 -0.132586  0.384315  0.276804  0.284012 -0.001078
#
#                 Adiponectin  Resistin     MCP.1  Classification
# Age               -0.219813  0.002742  0.013462       -0.043555
# BMI               -0.302735  0.195350  0.224038       -0.132586
# Glucose           -0.122121  0.291327  0.264879        0.384315
# Insulin           -0.031296  0.146731  0.174356        0.276804
# HOMA              -0.056337  0.231101  0.259529        0.284012
# Leptin            -0.095389  0.256234  0.014009       -0.001078
# Adiponectin        1.000000 -0.252363 -0.200694       -0.019490
# Resistin          -0.252363  1.000000  0.366474        0.227310
# MCP.1             -0.200694  0.366474  1.000000        0.091381
# Classification    -0.019490  0.227310  0.091381        1.000000

# %%
x=data[["BMI","Glucose","Insulin","Adiponectin"]]

# %%
y=data["Classification"]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.3)

# %%
from sklearn.linear_model import LogisticRegression 
logmodel=LogisticRegression()

# %%
logmodel.fit(x_train,y_train)
predictions = logmodel.predict(x_test)

# %%
data1 = x_test

# %%
len(x_test)
# Out:
# 35

# %%
data1
# Out:
#            BMI  Glucose  Insulin  Adiponectin
# 44   30.300000      102    8.340     8.130000
# 83   25.510204      112   10.395     5.486100
# 52   21.303949      102   13.852    21.056625
# 6    22.700000       77    4.690     5.589865
# 104  34.838148       95   12.548     2.364950
# 108  35.560000      131    8.150    11.900000
# 60   22.499637       95    5.261     4.771920
# 72   18.370000      105    6.030    12.760000
# 76   31.975015       92   16.635    11.018455
# 13   18.670000       88    6.107    36.060000
# 7    23.800000      118    6.470    13.251320
# 32   35.855815       87    8.576     4.794200
# 94   31.231410      131   30.130     8.404430
# 96   27.887617       99    9.208     5.478170
# 107  33.180000       92    5.750     9.160000
# 71   24.740000      106   58.460    16.100000
# 43   32.500000       93    5.430    11.787960
# 95   29.777778       70    8.396    10.731740
# 62   21.367521       78    2.640     3.886145
# 63   22.892820      103    2.740     9.349775
# 24   30.483158       90    5.537     9.731380
# 23   30.276817       84    4.376     9.048185
# 38   26.349292      103    5.138     2.194280
# 97   27.636054      103    2.432     6.783870
# 19   36.512637       87   14.026     5.100000
# 85   29.666548       85   14.649     7.282870
# 114  25.590000       82    2.820    33.750000
# 17   32.038959       85   18.077     7.780255
# 64   22.832879       98    6.862     4.230105
# 111  26.850000       92    3.330    12.100000
# 4    21.111111       92    3.549     4.819240
# 18   34.529723       95    4.427     5.462620
# 10   21.470000       78    3.469    13.110000
# 91   31.217482      100   18.077     9.923650
# 47   25.300000       60    3.508    10.567295

# %%
predictions
# Out:
# array([2, 2, 2, 1, 1, 2, 2, 2, 1, 2, 2, 1, 2, 2, 1, 2, 1, 1, 1, 2, 1, 1,
#        2, 2, 1, 1, 1, 1, 2, 1, 2, 1, 1, 2, 1])

# %% [markdown]
# Check Accuracy

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
knn= KNeighborsClassifier(n_neighbors=5)
knn.fit(x_train,y_train)
# Out:
# KNeighborsClassifier()

# %%
knn.score(x_test,y_test)
# Out:
# 0.6571428571428571

# %%
knn.score(x_train,y_train)
# Out:
# 0.8518518518518519

# %% [markdown]
# # Decission Tree

# %%
import math
import missingno as no
from sklearn.model_selection import train_test_split

# %%
data.head()
# Out:
#    Age        BMI  Glucose  Insulin      HOMA   Leptin  Adiponectin  Resistin  \
# 0   48  23.500000       70    2.707  0.467409   8.8071     9.702400   7.99585
# 1   83  20.690495       92    3.115  0.706897   8.8438     5.429285   4.06405
# 2   82  23.124670       91    4.498  1.009651  17.9393    22.432040   9.27715
# 3   68  21.367521       77    3.226  0.612725   9.8827     7.169560  12.76600
# 4   86  21.111111       92    3.549  0.805386   6.6994     4.819240  10.57635
#
#      MCP.1  Classification
# 0  417.114               1
# 1  468.786               1
# 2  554.697               1
# 3  928.220               1
# 4  773.920               1

# %%
data.tail()
# Out:
#      Age    BMI  Glucose  Insulin      HOMA  Leptin  Adiponectin  Resistin  \
# 111   45  26.85       92     3.33  0.755688   54.68        12.10     10.96
# 112   62  26.84      100     4.53  1.117400   12.45        21.42      7.32
# 113   65  32.05       97     5.73  1.370998   61.48        22.54     10.33
# 114   72  25.59       82     2.82  0.570392   24.96        33.75      3.27
# 115   86  27.18      138    19.91  6.777364   90.28        14.11      4.35
#
#       MCP.1  Classification
# 111  268.23               2
# 112  330.16               2
# 113  314.05               2
# 114  392.46               2
# 115   90.09               2

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 116 entries, 0 to 115
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Age             116 non-null    int64
#  1   BMI             116 non-null    float64
#  2   Glucose         116 non-null    int64
#  3   Insulin         116 non-null    float64
#  4   HOMA            116 non-null    float64
#  5   Leptin          116 non-null    float64
#  6   Adiponectin     116 non-null    float64
#  7   Resistin        116 non-null    float64
#  8   MCP.1           116 non-null    float64
#  9   Classification  116 non-null    int64
# dtypes: float64(7), int64(3)
# memory usage: 9.2 KB

# %% [markdown]
# Klasifikasi Decision Tree

# %%
# import library
from sklearn import tree
from matplotlib import pyplot as plt

# membuat klasifikasi Decision Tree
clf_tree = tree.DecisionTreeClassifier(criterion="entropy")
clf_tree = clf_tree.fit(x_train, y_train)

# %%
fig = plt.figure(figsize=(20,20))
_ = tree.plot_tree(clf_tree, feature_names=list(data.columns.values)[:9], class_names=list(data.columns.values)[9] ,filled=True)

# %% [markdown]
# Menghitung Akurasi Model Decision Tree

# %%
print("Score data train :", clf_tree.score(x_train, y_train))
print("Score data test  :", clf_tree.score(x_test, y_test))
# Out:
# Score data train : 1.0
# Score data test  : 0.6285714285714286
